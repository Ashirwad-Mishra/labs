# %%
f = open("test.txt","r")
f2 = open("test2.txt","r+")
v = f.read()
f2.write(v)
# Out:
# 292

# %%
with open("test.txt", "r") as f:
    v = f.read()
with open("test2.txt", "r+") as f2:
    f2.write(v)

# %%
f = open("test.txt","r")
v = f.read()
f.close()
f2 = open("test2.txt","r+")
f2.write(v)
f2.close()

# %%
with open("test.txt", "r") as f:
    v = f.read()
with open("test2.txt", "r+") as f2:
    f2.write(v)

# %%
f = open("test.txt","r")
v = f.read()
f.close()
f2 = open("test2.txt","r+")
f2.write(v)
f2.close()
