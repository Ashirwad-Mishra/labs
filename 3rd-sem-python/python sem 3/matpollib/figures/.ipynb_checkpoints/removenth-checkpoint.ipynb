# %%
def removenth( s , n):
    s2 = s[:n] + s[n + 1 : ]
    return s2

# %%
MyStr = "Bhadwa Abes"

# %%
print(removenth(MyStr , 4))
# Out:
# Bnada Abes

# %%
MyStr = input(" Enter your text: ")
# Out:
#  Enter your text:  Abes Chutiya College

# %%
removenth(MyStr , 4)
# Out:
# 'AbesChutiya College'

# %%
print(print(removenth(MyStr , 4)))
# Out:
# AbesChutiya College
# None
