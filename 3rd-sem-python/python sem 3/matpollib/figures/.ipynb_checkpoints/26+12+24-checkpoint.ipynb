# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = np.array([
    [12,
    34,
    45],[
    56,
    67,
    89]])

# %%
a
# Out:
# array([[12, 34, 45],
#        [56, 67, 89]])

# %%
a.ndim
# Out:
# 2

# %%
print(a[1, 2])
# Out:
# 89
